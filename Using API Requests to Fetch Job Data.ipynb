# %%
import requests
import json
import csv

# API URL and parameters
url = "https://indeed12.p.rapidapi.com/jobs/search"

querystring = {"query":"manager","location":"chicago","page_id":["1, 2"],"locality":"us","fromage":"1","radius":"50","sort":"date"}



# Headers for the API request
headers = {
	"x-rapidapi-key": "306724d89bmsh4751423d84c5c20p19198fjsnaa791a5ccb7c",
	"x-rapidapi-host": "indeed12.p.rapidapi.com"
}

# API request
response = requests.get(url, headers=headers, params=querystring)

# Check if the request was successful
if response.status_code == 200:
    data = response.json()  # Extract the JSON data

    # Pretty print the JSON structure to understand its format
    formatted_json = json.dumps(data, indent=4)
    print(formatted_json)  # Print to console

    # Specify the CSV file name
    csv_file = 'cyberjobsindeed_data.csv'

    # Open CSV file for writing
    with open(csv_file, mode='w', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)

        # Write the header row
        writer.writerow(["company_name", "formatted_relative_time", "id", "link", "locality",
                         "location", "pub_date_ts_milli", "salary"])

        # Write data rows
        if 'hits' in data:
            for job in data['hits']:
                # Validate job fields
                if all(key in job for key in ['company_name', 'formatted_relative_time', 'id', 'link', 'locality', 'location', 'pub_date_ts_milli']):
                    salary_info = job.get('salary', {})
                    salary_str = f"{salary_info.get('min', '')}-{salary_info.get('max', '')} {salary_info.get('type', '')}"
                    writer.writerow([
                        job['company_name'],
                        job['formatted_relative_time'],
                        job['id'],
                        job['link'],
                        job['locality'],
                        job['location'],
                        job['pub_date_ts_milli'],
                        salary_str
                    ])
                else:
                    print(f"Error: Missing job fields for job ID {job.get('id', '')}")

    print(f"Data successfully written to {csv_file}")

else:
    print(f"Error: Unable to fetch data (Status code: {response.status_code})")
# Out:
# {
#     "count": 15,
#     "hits": [
#         {
#             "company_name": "Uber",
#             "formatted_relative_time": "Just posted",
#             "id": "311bf712c6c4506f",
#             "link": "/job/311bf712c6c4506f?locality=us",
#             "locality": "us",
#             "location": "Chicago, IL",
#             "pub_date_ts_milli": 1726030800000,
#             "salary": {
#                 "max": 98000,
#                 "min": 79000,
#                 "type": "yearly"
#             },
#             "title": "Associate Enterprise Partner Manager, Grocery & Retail"
#         },
#         {
#             "company_name": "The Chicago Housing Authority",
#             "formatted_relative_time": "Just posted",
#             "id": "98730355d66378a9",
#             "link": "/job/98730355d66378a9?locality=us",
#             "locality": "us",
#             "location": "Chicago, IL 60661",
#             "pub_date_ts_milli": 1726030800000,
#             "salary": {
#                 "max": 90000,
#                 "min": 85000,
#                 "type": "yearly"
#             },
#             "title": "Manager, Digital Inclusion"
#         },
#         {
#             "company_name": "GroupM Nexus",
#             "formatted_relative_time": "Just posted",
#             "id": "64308950704cc01a",
#             "link": "/job/64308950704cc01a?locality=us",
#             "locality": "us",
#             "location": "Chicago, IL 60607",
#             "pub_date_ts_milli": 1726030800000,
#             "salary": {
#                 "max": 140000,
#                 "min": 60000,
#                 "type": "yearly"
#             },
#             "title": "Manager, Paid Social"
#         },
#         {
#             "company_name": "Adler University",
#             "formatted_relative_time": "Just posted",
#             "id": "85c1a491b5fb35b7",
#             "link": "/job/85c1a491b5fb35b7?locality=us",
#             "locality": "us",
#             "location": "Chicago, IL 60602",
#             "pub_date_ts_milli": 1726030800000,
#             "salary": {},
#             "title": "Manager, Campus Operations"
#         },
#         {
#             "company_name": "BMO US",
#             "formatted_relative_time": "Just posted",
#             "id": "b20158ce7c9c2641",
#             "link": "/job/b20158ce7c9c2641?locality=us",
#             "locality": "us",
#             "location": "Chicago, IL 60606",
#             "pub_date_ts_milli": 1726030800000,
#             "salary": {
#                 "max": 134500,
#                 "min": 72500,
#                 "type": "yearly"
#             },
#             "title": "Manager, Risk Strategy, Initiatives & Reporting"
#         },
#         {
#             "company_name": "Foursquare",
#             "formatted_relative_time": "Just posted",
#             "id": "d3db875d6d436a52",
#             "link": "/job/d3db875d6d436a52?locality=us",
#             "locality": "us",
#             "location": "Chicago, IL",
#             "pub_date_ts_milli": 1726030800000,
#             "salary": {
#                 "max": 120000,
#                 "min": 90000,
#                 "type": "yearly"
#             },
#             "title": "Enterprise Customer Success Manager"
#         },
#         {
#             "company_name": "Bimbo Bakeries USA",
#             "formatted_relative_time": "Just posted",
#             "id": "105d4e9379180bf9",
#             "link": "/job/105d4e9379180bf9?locality=us",
#             "locality": "us",
#             "location": "Chicago, IL",
#             "pub_date_ts_milli": 1725858000000,
#             "salary": {
#                 "max": 91900,
#                 "min": 70700,
#                 "type": "yearly"
#             },
#             "title": "Supervisor Customer Service Analytics"
#         },
#         {
#             "company_name": "Northwestern University",
#             "formatted_relative_time": "Just posted",
#             "id": "d79688abc26d9e2e",
#             "link": "/job/d79688abc26d9e2e?locality=us",
#             "locality": "us",
#             "location": "Evanston, IL",
#             "pub_date_ts_milli": 1726030800000,
#             "salary": {
#                 "max": 80000,
#                 "min": 74000,
#                 "type": "yearly"
#             },
#             "title": "Manager, External Communications"
#         },
#         {
#             "company_name": "United Airlines",
#             "formatted_relative_time": "Just posted",
#             "id": "49c9c7f47ff78f92",
#             "link": "/job/49c9c7f47ff78f92?locality=us",
#             "locality": "us",
#             "location": "Chicago, IL",
#             "pub_date_ts_milli": 1726030800000,
#             "salary": {},
#             "title": "Senior Manager - Digital Products (Hybrid)"
#         },
#         {
#             "company_name": "Salesforce",
#             "formatted_relative_time": "Just posted",
#             "id": "268b12cdf1089343",
#             "link": "/job/268b12cdf1089343?locality=us",
#             "locality": "us",
#             "location": "Chicago, IL 60654",
#             "pub_date_ts_milli": 1726030800000,
#             "salary": {
#                 "max": 217200,
#                 "min": 143500,
#                 "type": "yearly"
#             },
#             "title": "Senior Customer Success Manager, Data Cloud"
#         },
#         {
#             "company_name": "Mountain Manufacturing",
#             "formatted_relative_time": "Just posted",
#             "id": "ae3b3c58044823f7",
#             "link": "/job/ae3b3c58044823f7?locality=us",
#             "locality": "us",
#             "location": "Chicago, IL 60604",
#             "pub_date_ts_milli": 1726030800000,
#             "salary": {},
#             "title": "Business Development Manager"
#         },
#         {
#             "company_name": "The Chicago Housing Authority",
#             "formatted_relative_time": "Just posted",
#             "id": "370d8502b7c131fb",
#             "link": "/job/370d8502b7c131fb?locality=us",
#             "locality": "us",
#             "location": "Chicago, IL 60661",
#             "pub_date_ts_milli": 1726030800000,
#             "salary": {
#                 "max": 85000,
#                 "min": 80000,
#                 "type": "yearly"
#             },
#             "title": "Manager, Website"
#         },
#         {
#             "company_name": "Wesco",
#             "formatted_relative_time": "Just posted",
#             "id": "114c40f561f3cb20",
#             "link": "/job/114c40f561f3cb20?locality=us",
#             "locality": "us",
#             "location": "Glenview, IL 60026",
#             "pub_date_ts_milli": 1726030800000,
#             "salary": {
#                 "max": 133583,
#                 "min": 78578,
#                 "type": "yearly"
#             },
#             "title": "Manager - Credit and Collections"
#         },
#         {
#             "company_name": "Wesco",
#             "formatted_relative_time": "Just posted",
#             "id": "4b3b51cf9af0c708",
#             "link": "/job/4b3b51cf9af0c708?locality=us",
#             "locality": "us",
#             "location": "Alsip, IL",
#             "pub_date_ts_milli": 1726030800000,
#             "salary": {},
#             "title": "Project Manager I"
#         },
#         {
#             "company_name": "BMO US",
#             "formatted_relative_time": "Just posted",
#             "id": "51d2ea484f6fb28d",
#             "link": "/job/51d2ea484f6fb28d?locality=us",
#             "locality": "us",
#             "location": "Chicago, IL 60606",
#             "pub_date_ts_milli": 1726030800000,
#             "salary": {
#                 "max": 245000,
#                 "min": 190000,
#                 "type": "yearly"
#             },
#             "title": "Managing Director, Lead Financial Officer, Corporate Revenue"
#         }
#     ],
#     "indeed_final_url": "https://www.indeed.com/jobs?q=manager&l=chicago&fromage=1&radius=50&sort=date",
#     "next_page_id": 2,
#     "suggest_locality": null
# }
# Data successfully written to cyberjobsindeed_data.csv
